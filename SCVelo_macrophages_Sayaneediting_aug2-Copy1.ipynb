# %%
import scvelo as scv
import scanpy as sc
from matplotlib import pyplot as plt

# %%
adata = sc.read_h5ad('lola.h5ad')

# %%
scv.pl.proportions(adata)

# %%
scv.pp.filter_genes(adata, min_shared_counts=20)
scv.pp.normalize_per_cell(adata)
scv.pp.filter_genes_dispersion(adata, n_top_genes=2000)
scv.pp.log1p(adata)
# Out:
# Filtered out 24270 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.

# %%
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=2000)
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
# Out:
# Filtered out 55 genes that are detected 20 counts (shared).
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize spliced as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize unspliced as it looks processed already. To enforce normalization, set `enforce=True`.
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# WARNING: Did not modify X as it looks preprocessed already.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:01) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
scv.tl.velocity(adata)
# Out:
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)

# %%
scv.tl.velocity_graph(adata)
# Out:
# computing velocity graph (using 1/8 cores)
#   0%|          | 0/4408 [00:00<?, ?cells/s]
#     finished (0:00:06) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
sc.pl.umap(adata)

# %%
sc.pp.neighbors(adata, n_neighbors=20, n_pcs=None, use_rep=None, knn=True, random_state=0, method='umap')

# %%
sc.pl.umap(adata,color="RNA_snn_res.0.7")

# %%
adata.obs
# Out:
#                           orig.ident  nCount_RNA  nFeature_RNA  percent.mito  \
# S1_AAACCCACAACTTGCA  KA_E15_Liver_01      9156.0          2977      4.728094
# S1_AAACCCACAGACTGCC  KA_E15_Liver_01      6720.0          2605      4.638950
# S1_AAACGCTAGAAATTCG  KA_E15_Liver_01      2525.0          1257      5.629330
# S1_AAACGCTAGGTAGCAC  KA_E15_Liver_01      4018.0          1808      4.912542
# S1_AAACGCTGTACTGGGA  KA_E15_Liver_01      9037.0          3095      5.711789
# ...                              ...         ...           ...           ...
# S2_TTTGGTTCAACTTGGT  KA_E15_Liver_02      9856.0          3319      5.841621
# S2_TTTGGTTCAAGATCCT  KA_E15_Liver_02      6641.0          2529      5.540047
# S2_TTTGGTTGTCTCAAGT  KA_E15_Liver_02      8134.0          2917      5.570882
# S2_TTTGTTGAGACGCAGT  KA_E15_Liver_02      3437.0          1441      2.867225
# S2_TTTGTTGTCTAGAACC  KA_E15_Liver_02      6408.0          2635      4.941281
#
# ...

# %%
scv.pp.moments(adata)
# Out:
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:01) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %% [markdown]
# sc.pl.scatter(adata,color="RNA_snn_res.0.7")

# %% [markdown]
# sc.pl.scatter(adata,color="RNA_snn_res.0.7",palette={ "0": "red", "1": "orange", "2": "green", "3": "blue", "4": "red", "5": "orange", "6": "green", "7": "blue", "8": "blue", "9": "red" },basis = 'umap')

# %% [markdown]
# sc.pl.scatter(adata,color='RNA_snn_res.0.7',basis='umap',palette={ "0": "red", "1": "orange", "2": "green", "3": "blue", "4": "red", "5": "orange", "6": "green", "7": "blue", "8": "blue", "9": "red" })

# %% [markdown]
# #sc.pl.scatter(
#     adata,
#     color="RNA_snn_res.0.7",
#     palette={
#         "0": "red",
#         "1": "orange",
#         "2": "green",
#         "3": "blue",
#          "4": "red",
#         "5": "orange",
#         "6": "green",
#         "7": "blue",
#         "8": "blue",
#         "9": "red"
#     }
# )

# %%
scv.tl.velocity(adata)
# Out:
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)

# %%
scv.tl.velocity_graph(adata)
# Out:
# computing velocity graph (using 1/8 cores)
#   0%|          | 0/4408 [00:00<?, ?cells/s]
#     finished (0:00:07) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding_stream(adata,basis="umap",color="RNA_snn_res.0.7")
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.velocity_embedding(adata, basis="umap", color="RNA_snn_res.0.7", arrow_length=3, arrow_size=2, dpi=120)

# %% [markdown]
# Two more useful stats: - The speed or rate of differentiation is given by the length of the velocity vector. - The coherence of the vector field (i.e., how a velocity vector correlates with its neighboring velocities) provides a measure of confidence.

# %%
scv.tl.velocity_confidence(adata)
keys = 'velocity_length', 'velocity_confidence'
scv.pl.scatter(adata, c=keys, cmap='coolwarm', perc=[5, 95])
# Out:
# --> added 'velocity_length' (adata.obs)
# --> added 'velocity_confidence' (adata.obs)
# --> added 'velocity_confidence_transition' (adata.obs)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4408 × 1945
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'RNA_snn_res.0.5', 'RNA_snn_res.0.7', 'RNA_snn_res.0.9', 'RNA_snn_res.1.1', 'seurat_clusters', 'nCount_spliced', 'nFeature_spliced', 'nCount_unspliced', 'nFeature_unspliced', 'nCount_ambiguous', 'nFeature_ambiguous', 'nCount_SCT', 'nFeature_SCT', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'velocity_length', 'velocity_confidence', 'velocity_confidence_transition'
#     var: '_index', 'ambiguous_features', 'features', 'spliced_features', 'unspliced_features', 'gene_count_corr', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_gamma', 'velocity_qreg_ratio', 'velocity_r2', 'velocity_genes'
#     uns: 'neighbors', 'velocity_params', 'velocity_graph', 'velocity_graph_neg', 'RNA_snn_res.0.7_colors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'velocity_umap'
#     varm: 'PCs'
# ...

# %%
adata.var = adata.var.rename(columns={'_index': 'index'})

# %%
adata.var.set_index('index')
# Out:
#         ambiguous_features features spliced_features unspliced_features  \
# index
# Vcpip1              Vcpip1   Vcpip1           Vcpip1             Vcpip1
# Arfgef1            Arfgef1  Arfgef1          Arfgef1            Arfgef1
# Ube2w                Ube2w    Ube2w            Ube2w              Ube2w
# Mcm3                  Mcm3     Mcm3             Mcm3               Mcm3
# Smap1                Smap1    Smap1            Smap1              Smap1
# ...                    ...      ...              ...                ...
# Nxt2                  Nxt2     Nxt2             Nxt2               Nxt2
# Kdm5c                Kdm5c    Kdm5c            Kdm5c              Kdm5c
# Map3k15            Map3k15  Map3k15          Map3k15            Map3k15
# Ap1s2                Ap1s2    Ap1s2            Ap1s2              Ap1s2
# Ddx3y                Ddx3y    Ddx3y            Ddx3y              Ddx3y
#
#          gene_count_corr     means  dispersions  dispersions_norm  \
# index
# ...

# %%
adata.var = adata.var.drop(adata.var.columns[[1, 3, 4]],axis=1)

# %%
adata.var.set_index('index', drop=True, append=False, inplace=True, verify_integrity=False)

# %%
scv.tl.rank_velocity_genes(adata, groupby='RNA_snn_res.0.7', min_corr=.3)

df = scv.DataFrame(adata.var['features'])
df.head()
# Out:
# ranking velocity genes
#     finished (0:00:01) --> added
#     'rank_velocity_genes', sorted scores by group ids (adata.uns)
#     'spearmans_score', spearmans correlation scores (adata.var)
#         features
# index
# Vcpip1    Vcpip1
# Arfgef1  Arfgef1
# Ube2w      Ube2w
# Mcm3        Mcm3
# Smap1      Smap1

# %%
scv.tl.rank_velocity_genes(adata, groupby='RNA_snn_res.0.7', min_corr=.3)
# Out:
# ranking velocity genes
#     finished (0:00:00) --> added
#     'rank_velocity_genes', sorted scores by group ids (adata.uns)
#     'spearmans_score', spearmans correlation scores (adata.var)

# %%
scv.pl.velocity_graph(adata,basis="umap", color="RNA_snn_res.0.7",threshold=.1)

# %%
df = adata.obs.groupby('RNA_snn_res.0.7')[keys].mean().T
df.style.background_gradient(cmap='coolwarm', axis=1)
# Out:
# <style type="text/css">
# #T_d27f3_row0_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_d27f3_row0_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_d27f3_row0_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d27f3_row0_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_d27f3_row0_col4, #T_d27f3_row1_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d27f3_row0_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_d27f3_row0_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_d27f3_row0_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_d27f3_row0_col8 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_d27f3_row0_col9, #T_d27f3_row1_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d27f3_row1_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_d27f3_row1_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# ...

# %%
scv.pl.velocity(adata, ['C1qa','Cenpf','Top2','Ccnb1','Id3','S100a8','Ly6C'],color ='RNA_snn_res.0.7',basis ='umap',ncols=2, add_outline=False)

# %%
scv.pl.velocity(adata,['Top2a','Id3','S100a8','Ly6c2'],color ='RNA_snn_res.0.7',basis ='umap',ncols=2,save = 'plots.svg')
# Out:
# saving figure to file ./figures/scvelo_plots.svg

# %%
scv.pl.velocity(adata,'S100a8',ncols=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'S100a8'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# PAGA requires to install igraph, if not done yet.
# !pip install python-igraph --upgrade --quiet

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4408 × 1945
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'RNA_snn_res.0.5', 'RNA_snn_res.0.7', 'RNA_snn_res.0.9', 'RNA_snn_res.1.1', 'seurat_clusters', 'nCount_spliced', 'nFeature_spliced', 'nCount_unspliced', 'nFeature_unspliced', 'nCount_ambiguous', 'nFeature_ambiguous', 'nCount_SCT', 'nFeature_SCT', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'velocity_length', 'velocity_confidence', 'velocity_confidence_transition'
#     var: 'features', 'gene_count_corr', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_gamma', 'velocity_qreg_ratio', 'velocity_r2', 'velocity_genes', 'spearmans_score', 'velocity_score'
#     uns: 'neighbors', 'velocity_params', 'velocity_graph', 'velocity_graph_neg', 'RNA_snn_res.0.7_colors', 'rank_velocity_genes'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'velocity_umap'
#     varm: 'PCs'
# ...

# %%
x, y = scv.utils.get_cell_transitions(adata, basis='umap', starting_cell=518)
ax = scv.pl.velocity_graph(adata, c='lightgrey', edge_width=.05, show=False)
ax = scv.pl.scatter(adata, x=x, y=y, s=120, c='ascending', cmap='gnuplot', ax=ax)

# %%
scv.tl.velocity_pseudotime(adata)
scv.pl.scatter(adata, color='velocity_pseudotime', cmap='gnuplot')
# Out:
# computing terminal states
# WARNING: Uncertain or fuzzy root cell identification. Please verify.
#     identified 3 regions of root cells and 1 region of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)

# %%
# this is needed due to a current bug - bugfix is coming soon.
adata.uns['neighbors']['distances'] = adata.obsp['distances']
adata.uns['neighbors']['connectivities'] = adata.obsp['connectivities']

# %%
adata.obs[518:521]
# Out:
#                           orig.ident  nCount_RNA  nFeature_RNA  percent.mito  \
# S1_ATTCCTACACGCTTAA  KA_E15_Liver_01      5436.0          1776      4.888387
# S1_ATTCCTAGTCTTGTCC  KA_E15_Liver_01      5866.0          2134      4.838710
# S1_ATTCGTTGTCCTGGTG  KA_E15_Liver_01      5503.0          2351      5.380594
#
#                     RNA_snn_res.0.5 RNA_snn_res.0.7 RNA_snn_res.0.9  \
# S1_ATTCCTACACGCTTAA               6               9              11
# S1_ATTCCTAGTCTTGTCC               6               9              11
# S1_ATTCGTTGTCCTGGTG               4               2              10
#
#                     RNA_snn_res.1.1 seurat_clusters  nCount_spliced  ...  \
# S1_ATTCCTACACGCTTAA              12              12          5436.0  ...
# S1_ATTCCTAGTCTTGTCC              12              12          5866.0  ...
# S1_ATTCGTTGTCCTGGTG              11              11          5503.0  ...
#
#                      initial_size_unspliced  initial_size    n_counts  \
# ...

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4408 × 1945
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'RNA_snn_res.0.5', 'RNA_snn_res.0.7', 'RNA_snn_res.0.9', 'RNA_snn_res.1.1', 'seurat_clusters', 'nCount_spliced', 'nFeature_spliced', 'nCount_unspliced', 'nFeature_unspliced', 'nCount_ambiguous', 'nFeature_ambiguous', 'nCount_SCT', 'nFeature_SCT', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'velocity_length', 'velocity_confidence', 'velocity_confidence_transition', 'root_cells', 'end_points', 'velocity_pseudotime'
#     var: 'features', 'gene_count_corr', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_gamma', 'velocity_qreg_ratio', 'velocity_r2', 'velocity_genes', 'spearmans_score', 'velocity_score'
#     uns: 'neighbors', 'velocity_params', 'velocity_graph', 'velocity_graph_neg', 'RNA_snn_res.0.7_colors', 'rank_velocity_genes'
# ...

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4408 × 1945
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'RNA_snn_res.0.5', 'RNA_snn_res.0.7', 'RNA_snn_res.0.9', 'RNA_snn_res.1.1', 'seurat_clusters', 'nCount_spliced', 'nFeature_spliced', 'nCount_unspliced', 'nFeature_unspliced', 'nCount_ambiguous', 'nFeature_ambiguous', 'nCount_SCT', 'nFeature_SCT', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'velocity_length', 'velocity_confidence', 'velocity_confidence_transition', 'root_cells', 'end_points', 'velocity_pseudotime'
#     var: 'features', 'gene_count_corr', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_gamma', 'velocity_qreg_ratio', 'velocity_r2', 'velocity_genes', 'spearmans_score', 'velocity_score'
#     uns: 'neighbors', 'velocity_params', 'velocity_graph', 'velocity_graph_neg', 'RNA_snn_res.0.7_colors', 'rank_velocity_genes'
# ...

# %%
#colors for RNA_snn_res.0.9
#cluster 0 : #f8726b
#cluster 1 : #d99001
#cluster 2: #a3a600
#cluster 3 : #36b600
#cluster 4 : #00be7e
#cluster 5 : #03bfc4
#cluster 6 : #01b0f7
#cluster 7 : #9590fe
#cluster 8 : #e76cf3
#cluster 9 : #fe63bd

# %%
#adata.uns['RNA_snn_res.0.9_colors'] = ['#f8726b','#d99001','#a3a600','#36b600','#00be7e','#03bfc4','#01b0f7','#9590fe','#e76cf3','#fe63bd']

# %%
sc.pl.umap(adata,color="RNA_snn_res.0.7",
           palette={
               "0": "#f8726b",
               "1": "#d99001",
               "2": "#a3a600",
               "3": "#36b600",
               "4": "#00be7e",
               "5": "#03bfc4",
               "6": "#01b0f7",
               "7": "#9590fe",
               "8": "#e76cf3",
               "9": "#fe63bd"})

# %%
scv.tl.paga(adata,groups='RNA_snn_res.0.7')
# Out:
# running PAGA using priors: ['velocity_pseudotime']
#     finished (0:00:00) --> added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns)
#     'paga/transitions_confidence', velocity transitions (adata.uns)

# %%
scv.pl.velocity(adata, ['Ly6c2'],ncols=2,save='Ly6c2.svg')
# Out:
# saving figure to file ./figures/scvelo_Ly6c2.svg

# %%
df
# Out:
# RNA_snn_res.0.7             0         1         2         3         4  \
# velocity_length      5.520970  7.854429  6.053602  6.717229  5.455229
# velocity_confidence  0.791733  0.799937  0.788159  0.822869  0.819569
#
# RNA_snn_res.0.7             5         6         7         8          9
# velocity_length      6.424428  8.312345  5.884526  7.675794  10.840381
# velocity_confidence  0.797172  0.790413  0.836310  0.721614   0.848599

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4408 × 1945
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'RNA_snn_res.0.5', 'RNA_snn_res.0.7', 'RNA_snn_res.0.9', 'RNA_snn_res.1.1', 'seurat_clusters', 'nCount_spliced', 'nFeature_spliced', 'nCount_unspliced', 'nFeature_unspliced', 'nCount_ambiguous', 'nFeature_ambiguous', 'nCount_SCT', 'nFeature_SCT', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'velocity_length', 'velocity_confidence', 'velocity_confidence_transition', 'root_cells', 'end_points', 'velocity_pseudotime'
#     var: 'features', 'gene_count_corr', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'velocity_gamma', 'velocity_qreg_ratio', 'velocity_r2', 'velocity_genes', 'spearmans_score', 'velocity_score'
#     uns: 'neighbors', 'velocity_params', 'velocity_graph', 'velocity_graph_neg', 'RNA_snn_res.0.7_colors', 'rank_velocity_genes', 'paga', 'RNA_snn_res.0.7_sizes'
# ...

# %%
scv.pl.paga(adata, basis='umap', size=50, alpha=0.09,
min_edge_width=3, node_size_scale=1.5,col='RNA_snn_res.0.7',dashed_edges='connectivities')
# Out:
# WARNING: Invalid color key. Using grey instead.

# %%
adata.obs[3081:3100]
# Out:
#                           orig.ident  nCount_RNA  nFeature_RNA  percent.mito  \
# S2_CTACAGAGTACGAGTG  KA_E15_Liver_02      6720.0          2421      6.286581
# S2_CTACATTCAGTTCCAA  KA_E15_Liver_02      5951.0          2289      4.994558
# S2_CTACATTCATAGGTAA  KA_E15_Liver_02      7829.0          2663      5.796841
# S2_CTACATTGTCCCAAAT  KA_E15_Liver_02      8778.0          2966      4.393005
# S2_CTACCCACAATACGAA  KA_E15_Liver_02      4354.0          1945      4.117844
# S2_CTACCCACAATCTCTT  KA_E15_Liver_02      1162.0           752      2.603175
# S2_CTACCCATCTCGCTCA  KA_E15_Liver_02      7360.0          2714      4.853784
# S2_CTACCTGCACGTCGGT  KA_E15_Liver_02      5072.0          2105      5.221519
# S2_CTACCTGGTAACGGTG  KA_E15_Liver_02      5965.0          2264      5.798687
# S2_CTACCTGTCGCCTAGG  KA_E15_Liver_02      6206.0          2420      4.778930
# S2_CTACGGGAGATAGCTA  KA_E15_Liver_02      4807.0          1927      6.115108
# ...

# %%
x, y = scv.utils.get_cell_transitions(adata, basis='umap', starting_cell=0)
ax = scv.pl.velocity_graph(adata, c='lightgrey', edge_width=.05, show=False)
ax = scv.pl.scatter(adata, x=x, y=y, s=120, c='ascending', cmap='gnuplot', ax=ax)

# %% [markdown]
# #automating generating RNA velocity figures
# for i in range(0,3816):
#     x, y = scv.utils.get_cell_transitions(adata, basis='umap', starting_cell=i)
#     ax = scv.pl.velocity_graph(adata, c='lightgrey', edge_width=.05, show=False)
#     ax = scv.pl.scatter(adata, x=x, y=y, s=120, c='ascending', cmap='gnuplot', ax=ax,save='um'+str(i)+'.png', title = i )
#     # save the plot with a unique file name

# %%
scv.tl.recover_dynamics(adata)
# Out:
# recovering dynamics (using 1/8 cores)
#   0%|          | 0/535 [00:00<?, ?gene/s]
#     finished (0:02:47) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)

# %%
scv.tl.velocity(adata, mode='dynamical')
scv.tl.velocity_graph(adata)
# Out:
# computing velocities
#     finished (0:00:01) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/8 cores)
#   0%|          | 0/4408 [00:00<?, ?cells/s]
#     finished (0:00:02) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding_stream(adata, basis='umap')
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
df = adata.var
df = df[(df['fit_likelihood'] > .1) & df['velocity_genes'] == True]

kwargs = dict(xscale='log', fontsize=16)
with scv.GridSpec(ncols=3) as pl:
    pl.hist(df['fit_alpha'], xlabel='transcription rate', **kwargs)
    pl.hist(df['fit_beta'] * df['fit_scaling'], xlabel='splicing rate', xticks=[.1, .4, 1], **kwargs)
    pl.hist(df['fit_gamma'], xlabel='degradation rate', xticks=[.1, .4, 1], **kwargs)

scv.get_df(adata, 'fit*', dropna=True).head()
# Out:
#          fit_alpha  fit_beta  fit_gamma     fit_t_  fit_scaling  fit_std_u  \
# index
# Mcm3      1.200374  5.871496   0.363598   8.457666     0.086917   0.066461
# Neurl3    0.139612  0.622911   0.237087  11.918781     0.674726   0.062921
# Rnf149    1.273244  0.549807   0.481914  12.011769     0.525233   0.597033
# Slc40a1   1.311962  1.586223   0.074098  20.503916     0.130800   0.236207
# Hspd1     0.901957  4.811066   0.348139  11.127978     0.111920   0.058637
#
#          fit_std_s  fit_likelihood  fit_u0  fit_s0  fit_pval_steady  \
# index
# Mcm3      0.905468    3.210494e-01     0.0     0.0         0.469432
# Neurl3    0.112424    1.791960e-01     0.0     0.0         0.446133
# Rnf149    0.549405    2.936090e-01     0.0     0.0         0.408827
# Slc40a1   2.681715    1.310669e-17     0.0     0.0         0.499255
# Hspd1     0.742659    2.438204e-01     0.0     0.0         0.476526
#
#          fit_steady_u  fit_steady_s  fit_variance  fit_alignment_scaling  \
# index
# ...

# %%
scv.tl.latent_time(adata)
scv.pl.scatter(adata, color='latent_time', color_map='gnuplot', size=80)
# Out:
# computing latent time using root_cells as prior
#     finished (0:00:00) --> added
#     'latent_time', shared time (adata.obs)

# %%
top_genes = adata.var['fit_likelihood'].sort_values(ascending=False).index[:300]
scv.pl.heatmap(adata, var_names=top_genes, sortby='latent_time', col_color='RNA_snn_res.0.7', n_convolve=100)

# %%
top_genes = adata.var['fit_likelihood'].sort_values(ascending=False).index
scv.pl.scatter(adata, basis=top_genes[:15], ncols=5, frameon=False)

# %%
scv.tl.rank_dynamical_genes(adata, groupby='RNA_snn_res.0.7')
df = scv.get_df(adata, 'rank_dynamical_genes/names')
df.head(25)
# Out:
# ranking genes by cluster-specific likelihoods
#     finished (0:00:00) --> added
#     'rank_dynamical_genes', sorted scores by group ids (adata.uns)
#            0         1         2         3       4         5        6  \
# 0       Smc4     F13a1      Smc4     Top2a     Id3     F13a1    F13a1
# 1      Top2a       Fgr     F13a1      Smc4     Gda       Gda     Atf3
# 2       Srgn     Atad2     Hells      Smc2    Smc4      Smc4    Thbs1
# 3        Id3      Srgn      Mcm6     Kif11   F13a1       Fgr     Fosb
# 4      F13a1       Gda    Gpr141      Vcan     F10      Srgn      Gsr
# 5      Mki67       F10     Atad2    Incenp     App       Gsr      Gda
# 6      Thbs1      Smc4      Srgn       Gsr    Knl1      Vcan      Fyb
# 7     Incenp       Cfh      Orc6    S100a6    Srgn    S100a6     Ctss
# 8     Gpr141    S100a6     Tipin     Mki67     Gsr       F10   Mycbp2
# 9       Mcm6       Gsr       Cfh      Tpx2   Klf13       Cfh  Ccdc88a
# ...

# %%
pwd
# Out:
# '/Users/sshome/Desktop/E15_liver_analysis_sayane_Nov_2021/Art_code'

# %%
df.to_csv('dynamical_genes_macrophageclusters_Nov2022.csv')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4408 × 1945
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'RNA_snn_res.0.5', 'RNA_snn_res.0.7', 'RNA_snn_res.0.9', 'RNA_snn_res.1.1', 'seurat_clusters', 'nCount_spliced', 'nFeature_spliced', 'nCount_unspliced', 'nFeature_unspliced', 'nCount_ambiguous', 'nFeature_ambiguous', 'nCount_SCT', 'nFeature_SCT', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'velocity_length', 'velocity_confidence', 'velocity_confidence_transition', 'root_cells', 'end_points', 'velocity_pseudotime', 'latent_time'
# ...

# %%
#indexing is 1 to 4407

# %%
cluster_adata.obs[adata.obs['RNA_snn_res.0.7'== '0']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 cluster_adata.obs[adata.obs['RNA_snn_res.0.7'== '0']]
#
# NameError: name 'cluster_adata' is not defined

# %%
s13 = adata.obs

# %%
cluster_rownames.reset_index(drop=True)

# %%
cluster_rownames = s13[['RNA_snn_res.0.7']]

# %%
cluster_rownames.to_csv('cluster_rownames.csv')

# %% [markdown]
# #At unix shell rename all generated RNA-velocity figure graphs by this command : rename 's/^scvelo_um//' scvelo_um*.png

# %% [markdown]
# #sed 's/\r$//' cluster_rownames.txt > cluster_rownames_v2.txt #to remove trailing /r s because of editing in Macbook.

# %% [markdown]
# #command to seperate the files into different clusters : awk -F"," '{ print "mv",$1,$2}' cluster_rownames_v2.txt|sh

# %%
scv.pl.velocity_embedding_stream(adata,basis="umap",color="RNA_snn_res.0.7",save = 'RNA_velocity.svg')
# Out:
# saving figure to file ./figures/scvelo_RNA_velocity.svg
