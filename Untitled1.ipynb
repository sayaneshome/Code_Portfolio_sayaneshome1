# %%
# Install the remotes package 
install.packages('remotes')
# Out:
# The downloaded binary packages are in
# 	/var/folders/q9/_4dcnkx94yj_ybqwfvf0f43h0000gq/T//Rtmp95RL4x/downloaded_packages

# %%
remotes::install_version("SeuratObject", "4.1.4", repos = c("https://satijalab.r-universe.dev", getOption("repos")))
remotes::install_version("Seurat", "4.4.0", repos = c("https://satijalab.r-universe.dev", getOption("repos")))
# Out:
# ...
# digest    (0.6.33    -> 0.6.35   ) [CRAN]
# Rcpp      (1.0.11    -> 1.0.12   ) [CRAN]
# RcppEigen (0.3.3.9.3 -> 0.3.4.0.0) [CRAN]
# progressr (NA        -> 0.14.0   ) [CRAN]
# sp        (NA        -> 2.1-4    ) [CRAN]
# Installing 5 packages: digest, Rcpp, RcppEigen, progressr, sp
#
# Warning message in i.p(...):
# “installation of package ‘digest’ had non-zero exit status”
# Warning message in i.p(...):
# “installation of package ‘Rcpp’ had non-zero exit status”
# Warning message in i.p(...):
# “installation of package ‘RcppEigen’ had non-zero exit status”
# Warning message in i.p(...):
# “installation of package ‘/var/folders/q9/_4dcnkx94yj_ybqwfvf0f43h0000gq/T//Rtmp95RL4x/remotesbddd1493be8d/SeuratObject’ had non-zero exit status”
# ...
# sitmo        (NA         -> 2.0.2     ) [CRAN]
# BH           (1.81.0-1   -> 1.84.0-0  ) [CRAN]
# Rcpp         (1.0.11     -> 1.0.12    ) [CRAN]
# RcppEigen    (0.3.3.9.3  -> 0.3.4.0.0 ) [CRAN]
# spatstat.... (NA         -> 3.0-4     ) [CRAN]
# ...

# %%
# Enter commands in R (or R studio, if installed)
install.packages('Seurat')
library(Seurat)
# Out:
# Warning message:
# “dependency ‘Matrix’ is not available”
# also installing the dependencies ‘dotCall64’, ‘sitmo’, ‘spam’, ‘spatstat.random’, ‘deldir’, ‘FNN’, ‘dqrng’, ‘SeuratObject’, ‘fastDummies’, ‘lmtest’, ‘RANN’, ‘RcppAnnoy’, ‘RcppHNSW’, ‘RSpectra’, ‘Rtsne’, ‘scattermore’, ‘sctransform’, ‘spatstat.explore’, ‘spatstat.geom’, ‘uwot’
# The downloaded binary packages are in
# 	/var/folders/q9/_4dcnkx94yj_ybqwfvf0f43h0000gq/T//Rtmp95RL4x/downloaded_packages
# Warning message:
# “package ‘Seurat’ was built under R version 4.2.3”
# Loading required package: SeuratObject
#
# Warning message:
# “package ‘SeuratObject’ was built under R version 4.2.3”
# Loading required package: sp
#
# Error: package or namespace load failed for ‘SeuratObject’ in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]):
#  namespace ‘Matrix’ 1.4-1 is being loaded, but >= 1.6.3 is required
# Error: package ‘SeuratObject’ could not be loaded
# Traceback:
#
# 1. library(Seurat)
# ...

# %%
R.version.string
# Out:
# [1] "R version 4.2.1 (2022-06-23)"

# %%
remotes::install_version("SeuratObject", "3.0.0", repos = c("https://satijalab.r-universe.dev", getOption("repos")))
remotes::install_version("Seurat", "3.0.0", repos = c("https://satijalab.r-universe.dev", getOption("repos")))
# Out:
# Trying https://satijalab.r-universe.dev
#
# Trying https://cran.r-project.org
# Error in download_version_url(package, version, repos, type): version '3.0.0' is invalid for package 'SeuratObject'
# Traceback:
#
# 1. remotes::install_version("SeuratObject", "3.0.0", repos = c("https://satijalab.r-universe.dev",
#  .     getOption("repos")))
# 2. download_version_url(package, version, repos, type)
# 3. stop(sprintf("version '%s' is invalid for package '%s'", version,
#  .     package))

# %%
remotes::install_version("Seurat", version = "3.1.0")
# Out:
# ...
# BH           (1.81.0-1   -> 1.84.0-0  ) [CRAN]
# Rcpp         (1.0.11     -> 1.0.12    ) [CRAN]
# RcppEigen    (0.3.3.9.3  -> 0.3.4.0.0 ) [CRAN]
# stringi      (1.7.12     -> 1.8.3     ) [CRAN]
# plyr         (1.8.8      -> 1.8.9     ) [CRAN]
# digest       (0.6.33     -> 0.6.35    ) [CRAN]
# later        (1.3.1      -> 1.3.2     ) [CRAN]
# dplyr        (1.1.2      -> 1.1.4     ) [CRAN]
# fs           (1.6.3      -> 1.6.4     ) [CRAN]
# sass         (0.4.7      -> 0.4.9     ) [CRAN]
# bslib        (0.5.0      -> 0.7.0     ) [CRAN]
# robustbase   (NA         -> 0.99-2    ) [CRAN]
# multcomp     (NA         -> 1.4-25    ) [CRAN]
# mvtnorm      (NA         -> 1.2-4     ) [CRAN]
# MatrixModels (NA         -> 0.5-3     ) [CRAN]
# mnormt       (NA         -> 2.1.1     ) [CRAN]
# sn           (NA         -> 2.1.1     ) [CRAN]
# RcppArmad... (0.12.4.1.0 -> 0.12.8.2.1) [CRAN]
# promises     (1.2.0.1    -> 1.3.0     ) [CRAN]
# tidyr        (1.3.0      -> 1.3.1     ) [CRAN]
# ...
